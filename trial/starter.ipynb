# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
from datetime import timedelta, date
import pandas as pd
import sys

# %%
url="https://www.racing.com/form/2020-01-01/flemington#/form"

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
raw_html = simple_get(url) #Connection complete
    
    
html = BeautifulSoup(raw_html, 'html.parser')

# %%
print(html)
# Out:
# <!DOCTYPE html>
#
# <html id="ng-app" lang="en" ng-app="RVApp">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=11" http-equiv="X-UA-Compatible"/>
# <meta content="no" name="msapplication-tap-highlight">
# <meta content="telephone=no" name="format-detection"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport" viewport-modifier="">
# <meta content="yes" name="apple-mobile-web-app-capable">
# <meta content="app-id=com.racing.android" name="google-play-app"/>
# <meta content="RACING.COM" name="author">
# <meta content="Racing.com is Australia's premier resource for racing news, video, raceday information &amp; profiles. Watch live &amp; on-demand VIC &amp; SA horse racing anywhere, anytime Flemington - 01 Jan 2020" name="description"/>
# <meta content="horse racing, race horse, racing, victorian racing, south australian racing, racing victoria, spring racing, racehorse, thoroughbred racing, racing field and form, racing results, race results, your racing connection" name="keywords"/>
# <title>Flemington - Wed 01 Jan 2020 | RACING.COM</title>
# <!-- FORCING: {10CCC2CD-45F9-455D-B33E-9D21DDFA83A1} -->
# <link href="//cdn.racing.com/resources/Racing/css/utilities.046D9130F64AC80E3F3FF73CCA4031C5.min.css" rel="stylesheet" type="text/css"/>
# <link href="//cdn.racing.com/resources/Racing/css/global.532E0F36A99321FAD982AC400EA3D7FA.min.css" rel="stylesheet" type="text/css"/>
# <link href="//cdn.racing.com/resources/Racing/css/main.F49D09B4B320C65CAE730453EABCB0BA.min.css" rel="stylesheet" type="text/css"/>
# <link href="//cdn.racing.com/resources/racing/themes/racing/theme-racing-default.6E4B1D91B4A258BBA198187F451006E0.min.css" media="screen,print" rel="stylesheet" type="text/css">
# <script src="/layouts/app.aspx?ts=20200504" type="text/javascript"></script>
# <script src="//cdn.racing.com/resources/Racing/js/lib.ABBD7ADDB2E47BD8310EF7653DC91AFB.min.js"></script>
# <script src="//cdn.racing.com/resources/Racing/js/app.9B055D0C90245DA81EC0EB7B45A8ED9C.min.js"></script>
# <!--[if lt IE 9]>
#       <script src="/resources/Racing/js/lib/ie/html5shiv.3.7.0.min.js"></script>
#       <script src="/resources/Racing/js/lib/ie/respond.1.3.0.min.js"></script>
#       <script src="/resources/Racing/js/lib/ie/excanvas.js"></script>
# 	  <script src="/resources/Racing/js/lib/ie/es5-shim.min.js"></script>
#     <![endif]-->
# <!-- Google Analytics: Component 7432531c-9511-4764-aa5f-81295bc104c5 -->
# <script type="text/javascript">
# 	/* Functions */
# 	var getAnalyticsId = function () {
# 		try {
# 			if (document.cookie.length > 0) {
# 				var cookies = document.cookie.split("; ");
# 				for (var i = 0; i < cookies.length; i++) {
# 					var parts = cookies[i].split("=");
# 					if (parts.length === 2 && parts[0] == "rvprofile") {
# 						var profile = JSON.parse(decodeURIComponent(parts[1]));
# 						return profile.analyticsId;
# 					}
# 				}
# 			}
# 		} catch (err) {
# 		}
#
# 		return null;
# 	};
#
# 	var trackEvent = function (eventAction) {
# 		if (ga) {
# 			ga('send', {
# 				'hitType': 'event',
# 				'eventCategory': 'Racing+',
# 				'eventAction': eventAction,
# 			});
# 		}
# 	};
#
# 	var trackEventFromQueryString = function () {
# 		try {
# 			var qs = (function (a) {
# 				if (a == "") return {};
# 				var b = {};
# 				for (var i = 0; i < a.length; ++i) {
# 					var p = a[i].split('=', 2);
# 					if (p.length == 1)
# 						b[p[0]] = "";
# 					else
# 						b[p[0]] = decodeURIComponent(p[1].replace(/\+/g, " "));
# 				}
# 				return b;
# 			})(window.location.search.substr(1).split('&'));
#
# 			var messages = {
# 				"fsf": "new FB signup failure",
# 				"fss": "new FB signup success",
# 				"gsf": "new G+ signup failure",
# 				"gss": "new G+ signup success",
# 				"aoss": "activated owner signup success",
# 				"naoss": "non-activated owner signup success"
# 			};
#
# 			// Map the analytics event ('ae') query string parameter to a message
# 			var eventAction = messages[qs["ae"]];
# 			if (eventAction) {
# 				trackEvent(eventAction);
# 			}
# 		} catch (err) {
# 		}
# 	};
#
# 	/* Google Analytics script */
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-51692869-1', 'auto');
# 	ga('require', 'displayfeatures');
#
# 	var analyticsId = getAnalyticsId();
# 	if (analyticsId) {
# 		ga('set', 'userId', analyticsId);
# 	}
#
#     ga('send', 'pageview');
#     /**
#     * Function that tracks a click on an outbound link in Google Analytics.
#     * This function takes a valid URL string as an argument, and uses that URL string
#     * as the event label.
#     */
#     var trackOutboundLink = function (url) {
#     	ga('send', 'event', 'outbound', 'click', url, { 'hitCallback': function () { } });
#     	if(window.localStorage.Racing_jddebug == 1) console.log("trackOutboundLink:ga(","send","event","outbound","click",url,")");
#     };
#
#     var trackCustomAction = function(category, label, url, action) {
#         if (url != null) trackOutboundLink(url);
#         action = action || 'click';
#         ga('send', 'event', category, action, label, { 'hitCallback': function() {} });
#         if (window.localStorage.Racing_jddebug == 1) {
#             console.log("trackCustomAction:ga('send','event','" + category + "','" + action + "','" + label + "')");
#             console.log('analytics id is:', analyticsId);
#         }
#     };
#
#     var trackCrownbet = function(url, label) {
#     	trackOutboundLink(url);
#     	ga('send','event','CrownBet','click', label, { 'hitCallback': function () { } });
#     };
#
#     var crownbetGA = function(label) {
#     	dataLayer.push({'Odds': label, 'event':'CrownBet'});
#     }
#
#     trackEventFromQueryString();
# </script>
# <!-- End Google Analytics -->
# <!-- Salesforce Marketing Cloud Analytics -->
# <script src="https://7234365.collect.igodigital.com/collect.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#     /* Functions */
#     var getUserProfile = function () {
#         try {
#             if (document.cookie.length > 0) {
#                 var cookies = document.cookie.split("; ");
#                 for (var i = 0; i < cookies.length; i++) {
#                     var parts = cookies[i].split("=");
#                     if (parts.length === 2 && parts[0] == "rvprofile") {
#                         var profile = JSON.parse(decodeURIComponent(parts[1]));
#                         if (profile.email && profile.contactId) {
#                             return profile;
#                         }
#                     }
#                 }
#             }
#         } catch (err) {
#         }
#
#         return null;
#     };
#
#     /* Custom event tracking */
#     function trackEventInSFMC(eventName, attributeName, attributeValue)
#     {
#         //_etmc.push(["setOrgId", "7234365"]);
#         _etmc.push(["trackEvent", {
#             "name": eventName,
#             "details":
#                 {
#                     attributeName : attributeValue
#                 }
#         }]);
#     };
#
#     $(document).ready(function() {
#         /* Base SFMC tracking calls */
#
#         if (_etmc) {
#             _etmc.push(["setOrgId", "7234365"]);
#
#             var profile = getUserProfile();
#
#             //If profile is undefined, user is anonymous
#             if (profile) {
#                 _etmc.push(["setUserInfo", {
#                     "email": profile.email,
#                     "details": {
#                         "contactId": profile.contactId
#                     }
#                 }]);
#             }
#
#             _etmc.push(["trackPageView"]); /* Browser used, location etc. */
#         }
#     });
#
# </script>
# <meta content="Flemington - 01 Jan 2020" property="og:title"/>
# <meta content="RACING.COM" property="og:site_name"/>
# <meta content="http://www.racing.com/form/2020-01-01/flemington" property="og:url"/>
# <meta content="Flemington - 01 Jan 2020" property="og:description"/>
# <meta content="//cdn.racing.com/resources/Racing/img/favicon/hub/favicon-200x200.png" property="og:image"/>
# <meta content="website" property="og:type"/>
# <script type="text/javascript"> var googletag = googletag || {}; googletag.cmd = googletag.cmd || []; googletag.cmd.push(function () { googletag.pubads().setTargeting("advelvet", (Math.floor(Math.random() * 20) + 1) + ""); }); </script>
# <script type="text/javascript">
# var PWT={}; //Initialize Namespace
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# PWT.jsLoaded = function(){ //PubMatic pwt.js on load callback is used to load GPT
#     (function() {
#         var gads = document.createElement('script');
#         var useSSL = 'https:' == document.location.protocol;
#         gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
#         var node = document.getElementsByTagName('script')[0];
#         node.parentNode.insertBefore(gads, node);
#     })();
# };
#         (function() {
#             if ((navigator.userAgent.indexOf('iPhone') > 0 && navigator.userAgent.indexOf('iPad') == -1) || navigator.userAgent.indexOf('iPod') > 0 || navigator.userAgent.indexOf('Android') > 0 || navigator.userAgent.indexOf('windows') > 0) {
#                 var ProfileId = 1154; // profileId for mobile
#             } else {
#                 var ProfileId = 1153; // profile id for desktop
#             }
#             var purl = window.location.href;
#             var useSSL = 'https:' == document.location.protocol;
#             var url = (useSSL ? 'https:' : 'http:') + '//ads.pubmatic.com/AdServer/js/pwt/111788/' + ProfileId;
#             var profileVersionId = '';
#             if (purl.indexOf('pwtv=') > 0) {
#                 var regexp = /pwtv=(.*?)(&|$)/g;
#                 var matches = regexp.exec(purl);
#                 if (matches.length >= 2 && matches[1].length > 0) {
#                     profileVersionId = '/' + matches[1];
#                 }
#             }
#             var wtads = document.createElement('script');
#             wtads.async = true;
#             wtads.type = 'text/javascript';
#             wtads.src = url + profileVersionId + '/pwt.js';
#             var node = document.getElementsByTagName('script')[0];
#             node.parentNode.insertBefore(wtads, node);
#         })();
#     </script><script type="text/javascript">
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function() {
#   var mappingLeaderboard = googletag.sizeMapping().
#         addSize([768, 0], [728, 90]).
#                 addSize([0, 0], [[320, 50],[300, 50]]).
#                 build();
#   var mappingMrec = googletag.sizeMapping().
#         addSize([768, 0], [300, 250]).
#         addSize([0, 0], [0, 0]).
#         build();
#   var mapping1x1 = googletag.sizeMapping().
#         addSize([768, 0], [1, 1]).
#         addSize([0, 0], [0, 0]).
#         build();
# });
# </script>
# <link href="/resources/Racing/img/favicon/hub/favicon.ico" rel="shortcut icon"/>
# <link href="/resources/Racing/img/favicon/hub/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/resources/Racing/img/favicon/hub/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/resources/Racing/img/favicon/hub/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/resources/Racing/img/favicon/hub/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/resources/Racing/img/favicon/hub/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/resources/Racing/img/favicon/hub/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/resources/Racing/img/favicon/hub/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/resources/Racing/img/favicon/hub/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <meta content="Racing" name="apple-mobile-web-app-title"/>
# <link href="/resources/Racing/img/favicon/hub/favicon-196x196.png" rel="icon" sizes="196x196" type="image/png"/>
# <link href="/resources/Racing/img/favicon/hub/favicon-160x160.png" rel="icon" sizes="160x160" type="image/png"/>
# <link href="/resources/Racing/img/favicon/hub/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/resources/Racing/img/favicon/hub/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/resources/Racing/img/favicon/hub/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <meta content="#ffc40d" name="msapplication-TileColor"/>
# <meta content="/resources/Racing/img/favicon/hub/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="/resources/Racing/img/favicon/hub/browserconfig.xml" name="msapplication-config"/>
# <meta content="Racing" name="application-name"/>
# <meta content="app-id=905132729" name="apple-itunes-app"/>
# <meta content="wyd8aZ4lByVSh1hmWlZamJ1LBsA" name="alexaVerifyID">
# <meta content="#ed1c24" name="theme-color"/>
# <meta content="113981269012695" property="fb:app_id">
# <!--RV Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
# fbq('init', '1631310827106969');
# fbq('track', "PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=1631310827106969&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- FIX PREROLL AD NOT SHOWING IN CHROME -->
# <style type="text/css">
# .vjs-ima3-ad-container video {height: auto !important;}
#
# </style>
# <script>
# jQuery( document ).ready(function() {
#     jQuery( "#masthead_0_lnkLiveVision" ).click(function() {
#   document.location.href = 'https://www.racing.com/live-vision.aspx'
# });
#   jQuery( "#masthead_0_lnkMenuWatchLive" ).click(function() {
#   document.location.href = 'https://www.racing.com/live-vision.aspx'
# });
#
# });
#
# </script>
# <style>
# @media only screen and (max-width: 768px) {
#   ul.article-list li .meta .author {
#     display: none;
#   }
# }
# </style>
# <style>
# .footer .newsletter li.newsletter-footer h3 {
#     display: none;
# }
# .footer .newsletter li.newsletter-footer .mc-footer-panel .left input.email, .footer .newsletter li.newsletter-footer .mc-footer-panel .right input.email {
#     display: none;
# }
# .footer .newsletter li.newsletter-footer .mc-footer-panel .right input[type='button'] {
#     display: none;
# }
# @media only screen and (max-width: 768px) {
# #asmBannerWidgetContainer {
#     height: 200px !important;
#   }
# }
# </style><script type="text/javascript">
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function() {
#
#   var mappingLeaderboard = googletag.sizeMapping().
# 		addSize([768, 0], [728, 90]).
#                 addSize([0, 0], [320, 50]).
#                 build();
#
#   var mappingMrec = googletag.sizeMapping().
# 		addSize([768, 0], [300, 250]).
# 		addSize([0, 0], [0, 0]).
# 		build();
#
#   var mapping1x1 = googletag.sizeMapping().
# 		addSize([768, 0], [1, 1]).
# 		addSize([0, 0], [0, 0]).
# 		build();
# googletag.defineSlot('/305590751/racing/relaxedracing', [1, 1], '1x1').defineSizeMapping(mapping1x1).addService(googletag.pubads());
# googletag.defineSlot('/305590751/racing/relaxedracing', [300, 250], 'topmrec').defineSizeMapping(mappingMrec).addService(googletag.pubads()).setTargeting('pos', 'top');
# googletag.defineSlot('/305590751/racing/relaxedracing', [300, 250], 'bottommrec').defineSizeMapping(mappingMrec).addService(googletag.pubads()).setTargeting('pos', 'bottom');
# googletag.defineSlot('/305590751/racing/relaxedracing', [[320, 50],[300, 50],[728, 90]], 'bottomlb').defineSizeMapping(mappingLeaderboard).addService(googletag.pubads()).setTargeting('pos', 'bottom');
# googletag.defineSlot('/305590751/racing/relaxedracing', [[320, 50],[300, 50],[728, 90]], 'toplb').defineSizeMapping(mappingLeaderboard).addService(googletag.pubads()).setTargeting('pos', 'top');
# googletag.enableServices();
# });
# </script><script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/305590751/racing/WSPformdesktop', [624, 56], 'div-gpt-ad-1576552757651-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# </meta></meta></link></meta></meta></meta></meta></head>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"678c050173","applicationID":"5594901","transactionName":"NFRWMEtRX0dQU0JYCg0edTdpH11VSF9DRRZMQ1UHUF5WG1xRRUUAER9VF0lI","queueTime":0,"applicationTime":355,"ttGuid":"2BC90626C09A26E8","agent":""}</script><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"XQIOVldXGwYFXVVbBwA=",licenseKey:"678c050173",applicationID:"5594901"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(25),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(26),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){L++,C=g.hash,this[u]=y.now()}function o(){L--,g.hash!==C&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable){var x=t(10),b=t(11),E=t(8),O=t(6),R=t(13),P=t(7),T=t(14),N=t(9),M=t("ee"),S=M.get("tracer");t(16),y.features.spa=!0;var C,L=0;M.on(u,r),M.on(p,r),M.on(d,o),M.on(l,o),M.buffer([u,d,"xhr-done","xhr-resolved"]),O.buffer([u]),R.buffer(["setTimeout"+c,"clearTimeout"+s,u]),T.buffer([u,"new-xhr","send-xhr"+s]),P.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),N.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,"send-xhr"+s),a(M,"xhr-resolved"),a(M,"xhr-done"),a(P,m+s),a(P,m+"-done"),a(N,"new-jsonp"),a(N,"jsonp-end"),a(N,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,L>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var n=t[0];n instanceof x&&i("bst",[n, ...
# <!-- analytics -->
# <!-- Google Tag Manager -->
# <script type="text/javascript">
# (function(w, d, s, l, i) {
#    w[l] = w[l] || [];
#    w[l].push({
#        'gtm.start': new Date().getTime(),
#        event: 'gtm.js'
#    });
#    var f = d.getElementsByTagName(s)[0],
#        j = d.createElement(s),
#        dl = l != 'dataLayer' ? '&l=' + l : '';
#    j.async = true;
#    j.src =
#        '//www.googletagmanager.com/gtm.js?id=' + i + dl;
#    f.parentNode.insertBefore(j, f);
# })(window, document, 'script', 'dataLayer', 'GTM-NJJTCC');
# </script>
# <!-- End Google Tag Manager -->
# <script type="”application/ld+json”">
# { “@context” : “http://schema.org”,
# “@type” : “Organization”,
# “name” : “Racing.com”,
# “url” : “https://racing.com”,
# “sameAs” : [ “https://www.facebook.com/racingdotcom/”,
# “https://twitter.com/Racing”,
# “https://www.instagram.com/racingdotcom/”,
# “https://www.youtube.com/channel/UCn0dCf3kt0tGfU9_yXayY7Q”,
# “https://au.linkedin.com/company/racing-com”,]
# }
# </script>
# <form action="/form/2020-01-01/flemington" id="theForm" method="post" novalidate="">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="QUoDExro/qjURkHqsrg8ogbsf6NBGi21ObThNUWu5Dz8KbsA+KfvetG4/DOrhx/5w/NI/J7QFlnzlM1CA44zbCFWW7M="/>
# </div>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="285B94B2"/>
# <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="XJOVkDfacBBW+hHmsz9/MOl9Nij6jMG4xi3i1+zr2fps8gDoBl7GMbkdljMWEc/GbYeG2l3DrueeWnzxYr2M43X6fJFPGobLRE6lUWYO5LJ6+Oxx"/>
# </div>
# <div id="fb-root"></div>
# <!-- masthead -->
# <!--add CLUB MENU in Mast head -->
# <!-- fixed-navbar DESKTOP for Hub site-->
# <div class="navbar navbar-default sticky top" id="masthead_0_divHubNav" ng-controller="navigationController" ng-init="id='desktop';navContext='hub';" role="navigation">
# <div class="first-tier">
# <div class="container">
# <a class="desktop logo" href="/" onclick="goToUrl('/');">
# <svg id="Layer_1" style="enable-background: new 0 0 487.7 55.9;" version="1.1" viewbox="0 0 487.7 55.9" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path d="M300.1,39.4c-4.6,0-8.9,3.7-9.8,8.3c-0.9,4.6,2,8.2,6.6,8.2c4.6,0,9-3.6,9.9-8.2C307.7,43.1,304.7,39.4,300.1,39.4z"></path>
# <path d="M344.6,12.8c4.4,0,7.7,0.8,12.7,3l2.4-12.4c-3-2.2-8.4-3.5-14-3.5C325,0,314,13.2,311.2,28c-2.9,14.8,2.9,28,23.7,28c5.6,0,11.5-1.2,15.3-3.4l2.4-12.4c-5.9,2.3-9.5,3-13.9,3c-12.2,0-13.3-7.9-11.9-15.2C328.2,20.7,332.3,12.8,344.6,12.8z"></path>
# <path d="M391.9,0C373.4,0,362,12.5,359,27.8c-3,15.4,3.5,28.1,22,28.1c18.3,0,29.9-12.7,32.9-28.1C416.8,12.5,410.2,0,391.9,0z M398.3,27.8c-1.9,9.7-7.3,16-14.9,16c-7.6,0-10.7-6.3-8.8-16c1.9-9.6,7.3-15.7,14.9-15.7C397.2,12.1,400.1,18.2,398.3,27.8z"></path>
# <a class="linked" ng-class="{abandoned: race.isCancelled, changed: mainNavRaceCountdownChanged, secs: mainNavRaceCountdownSecs}" ng-href="https://www.racing.com/form/{{race.Url.MeetUrlSegment}}/{{race.Url.RacePrefix}}/{{race.Url.RaceNumber}}" ng-repeat="race in result | filter:upcomingFilter | limitTo:1">
# <span class="icon racing-icon">g</span>
# <span class="text" ng-switch="race.TimeUntil">{{ race.ShortTrack }} R{{ race.Number }} <span ng-switch-default="">in </span><span ng-switch-when="Tomorrow">- </span><span class="time">{{race.TimeUntil}}</span></span>
# </a>
# </div>
# </div>
# <div class="icons">
# <div class="c-watch-now c-watch-now--inline" ng-cloak="" ng-controller="epgController" ng-init="initMasthead(0, 2);">
# <a href="javascript:void(0);" ng-click="loadUserStateModal(false);">
# <div class="c-watch-now-play-button">
# <span class="c-watch-now__button">
# <i class="racing-icon">Q</i>
# </span>
# </div>
# <!--
#                         <div class="c-watch-now__inner">
#                             <div class="c-watch-now__box">
#                                 <div class="c-watch-now__on-now">
#                                     On Air&nbsp;&nbsp;<b class="c-watch-now__blinky">&#8226;</b>
#                                 </div>
#                                 <div class="c-watch-now__show">
#                                     <div class="c-watch-now__text">
#                                         <span>{{currentProgram.title}}</span>
#                                     </div>
#                                 </div>
#                                 <span class="c-watch-now__button">
#                                     <i class="racing-icon">Q</i>
#                                 </span>
#                             </div>
#                         </div>
#                             -->
# </a>
# </div>
# <span class="item search">
# <a href="javascript:trackCustomAction('Live vision &amp; radio','RSN play button - global header', null, 'Click to play');" onclick="popUpWindow('/live-audio.html', 'RSN', 450, 160);">
# <i class="icon racing-icon">o</i>
# </a>
# </span>
# <span class="item">
# <div class="global-search-container" role="search">
# <div class="search-textbox-container" ng-class="{'active': searchBoxActive}" ng-model="searchContainer">
# <button class="search-btn" ng-click="searchTxt();" type="button"><i class="racing-icon icon">M</i></button>
# <input class="global-search" ng-blur="hideTxt();" ng-change="updateSearch();" ng-focus="showHideTextCross();" ng-keydown="navigateToSearch($event);" ng-model="searchKeyword" placeholder="Search..." type="text"/>
# <span class="racing-icon icon clear-search" ng-class="{'show': showClearTextBtn}" ng-click="activateClearButton();">N</span>
# </div>
# <div class="search-results smaller-view quick-search" ng-class="{'expose': autoSuggestActive}" ng-cloak="">
# <div class="site-results" ng-repeat="siteResult in quickSearchHeader | orderBy: 'IsClubItem' : false">
# <div class="uppercase title">{{siteResult.SiteUrl}} Results</div>
# <div class="tc" e-link="{{result.ContentUrl}}" ng-class="{'active' : (focusedResult == $index), 'club' : (siteResult.IsClubItem)}" ng-keydown="navigateToSearch($event)" ng-repeat="result in quickSearchResult | filter: siteResultsFilter(siteResult.SiteUrl)" target="self">
# <div class="t fright">
# <span class="racing-icon icon">{{result.CategoryIcon}}</span>
# </div>
# <div class="c">
# <h4 ng-if="result.EventName &amp;&amp; siteName === 'crv'">{{result.EventName}}</h4>
# <h4>{{result.ContentTitle}}</h4>
# </div>
# <div class="banner" ng-if="result.ContentDate">
# <h5 class="content-date">{{result.ContentDate}}</h5>
# </div>
# </div>
# </div>
# <div class="tc all" e-link="/search?q={{searchText}}" ng-class="{'active' : (focusedResult == quickSearchResult.length)}" ng-keydown="navigateToSearch($event);" ng-show="quickSearchResult.length" target="self">
# <div class="c">
# <h4>View all <span ng-if="quickSearchTotalResults">{{quickSearchTotalResults}}</span> results</h4>
# </div>
# </div>
# </div>
# </div>
# </span>
# </div>
# </div>
# </div>
# <div class="second-tier">
# <div class="container">
# <div class="navbar-collapse collapse nopadding rv-menu">
# <ul class="nav navbar-nav navbar-left" ng-mouseenter="navbarHovering = true;" ng-mouseleave="navbarHovering = false;">
# <li ng-class="{'active': dropDowns[0].active, 'iDontHaveThePower': dropDownActive()}">
# <a class="racing" href="/" ng-click="clickIntent(0,0); $event.preventDefault();" ng-mouseenter="hoverInTent(0, true);" ng-mouseleave="hoverInTent(0, false);hoverOutDevice(0);">
# <span>Racing</span>
# </a>
# <span class="triangle"></span>
# </li>
# <li ng-class="{'active': dropDowns[1].active, 'iDontHaveThePower': dropDownActive()}">
# <a class="news" href="/news" ng-click="clickIntent(1,0); $event.preventDefault();" ng-mouseenter="hoverInTent(1, true);" ng-mouseleave="hoverInTent(1, false);hoverOutDevice(1);">
# <span>News</span>
# </a>
# <span class="triangle"></span>
# </li>
# <li ng-class="{'active': dropDowns[2].active, 'iDontHaveThePower': dropDownActive()}">
# <a class="video" href="/videos" ng-click="clickIntent(2,0); $event.preventDefault();" ng-mouseenter="hoverInTent(2, true);" ng-mouseleave="hoverInTent(2, false);hoverOutDevice(2);">
# <span>Video</span>
# </a>
# <span class="triangle"></span>
# </li>
# <li ng-class="{'active': dropDowns[3].active, 'iDontHaveThePower': dropDownActive()}">
# <a class="calendar" href="/calendar" ng-click="clickIntent(3,0); $event.preventDefault();" ng-mouseenter="hoverInTent(3, true);" ng-mouseleave="hoverInTent(3, false);hoverOutDevice(3);">
# <span>Calendar</span>
# </a>
# <span class="triangle"></span>
# </li>
# <li ng-class="{'active': dropDowns[4].active, 'iDontHaveThePower': dropDownActive()}">
# <a class="profiles" href="javascript:void(0);" ng-click="clickIntent(4,0); $event.preventDefault();" ng-mouseenter="hoverInTent(4, true);" ng-mouseleave="hoverInTent(4, false);hoverOutDevice(4);">
# <span>Profiles &amp; Stats</span>
# </a>
# <span class="triangle"></span>
# </li>
# <li ng-class="{'active': dropDowns[5].active, 'iDontHaveThePower': dropDownActive()}">
# <a class="club" href="javascript:void(0);" ng-click="clickIntent(5,0); $event.preventDefault();" ng-mouseenter="hoverInTent(5, true);" ng-mouseleave="hoverInTent(5, false);hoverOutDevice(5);">
# <span>Clubs</span>
# </a>
# <span class="triangle"></span>
# </li>
# <li ng-class="{'active': dropDowns[6].active, 'iDontHaveThePower': dropDownActive()}">
# <a class="external" href="https://pick7.racing.com/" id="masthead_0_ancDtTopMenuLinkItem" ng-mouseenter="hoverInTent(6, true);" ng-mouseleave="hoverInTent(6, false);hoverOutDevice(6);" target="_blank">
# <span id="masthead_0_spDtTopMenuLinkItem">Pick 7</span>
# </a>
# </li>
# </ul>
# <div class="navbar-right">
# <div class="navbar-signin" ng-controller="loginController" ng-init="initPage();$root.isLiveAuthorize=true;$root.commercialSite=false;$root.loginSubscriptionId='-1';$root.isReachLimit=true;$root.isExpired=true; $root.isCommercialActive=false;$root.customerEmailID='';">
# <script id="loginModal.html" type="text/ng-template">
# 		<div class="modal" role="dialog">
# 			<div class="modal-dialog modal-login">
#                 <div class="modal-close">
#                     <button class="racing-icon close" type="button" ng-click="closeModal()"><span class="racing-icon">N</span></button>
#                 </div>
# 				<div class="modal-content">
# 					<div class="modal-header">
#                        <span class="logo"><img src="/resources/racing/img/logos/logo-racing-plus.png" width="150" height="25"/></span>
# 						<h3 class="modal-title">{{loginModalMessage}}</h3>
# 					</div>
#
# 					<div class="modal-body">
# 						<div class="login-form">
# 							<div class="social-buttons">
# 								<a href="https://id.racing.com/auth/signin/facebook?wa=wsignin1.0&wtrealm=https%3a%2f%2fwww.racing.com%2f&wreply=https%3a%2f%2fwww.racing.com%2fredirect.ashx%3fref%3d%252fform%252f2020-01-01%252fflemington" class="fb-login"><i class="icon-facebook"></i> <span>Log in with Facebook</span></a>
# 								<a href="https://id.racing.com/auth/signin/google?wa=wsignin1.0&wtrealm=https%3a%2f%2fwww.racing.com%2f&wreply=https%3a%2f%2fwww.racing.com%2fredirect.ashx%3fref%3d%252fform%252f2020-01-01%252fflemington" class="g-login"><i class="icon-googleplus"></i> <span>Log in with Google</span></a>
# 								<div class="form-message error" ng-show="(!formIsValid(loginForm) || forceShowError) && errorPosition == 'left'" >
# 									<span class="errorMessage">{{ errorMessage }}</span>
# 								</div>
# 							</div>
#
# 							<div class="login-divider">
# 								<div class="divider-line"></div>
# 								<span>or</span>
# 								<div class="divider-line bottom"></div>
# 							</div>
#
# 							<form name="loginForm" ng-hide="showForgotPassword" action="https://id.racing.com/auth/signin?wa=wsignin1.0&wtrealm=https%3a%2f%2fwww.racing.com%2f&wreply=https%3a%2f%2fwww.racing.com%2fredirect.ashx%3fref%3d%252fform%252f2020-01-01%252fflemington" method="POST" novalidate>
# 								<input type="email" name="email" id="email" placeholder="email" ng-model="usernameField" ng-focus="formFieldFocus()" required />
# 								<input type="password" name="password" id="password" placeholder="password" ng-model="passwordField" ng-focus="formFieldFocus()" required />
# 								<div class="checkbox" ng-init="isPersistent=true">
# 									<label class="small"><input type="checkbox" name="isPersistent" ng-model="isPersistent" value="true" id="isPersistent"/> Keep me logged in</label>
# 								</div>
# 								<div class="form-message error" ng-show="(!formIsValid(loginForm) || forceShowError) && errorPosition == 'right'" >
# 									<span class="errorMessage">{{ errorMessage }}</span>
# 								</div>
# 								<button type="submit" value="Log in" ng-disabled="loginForm.$invalid">Log in</button>
#
# 								<p class="small"><a href="/plus?fp=1" target="_self">Forgot your password?</a></p>
# 							</form>
# 						</div>
# 					</div>
#
# 					<div class="bottom-text tcenter">Don't have an account? <a href="/plus/signup?ref=/form/2020-01-01/flemington" target="_self" class="sign-up-link">Sign up</a></div>
# 				</div>
# 			</div>
# 		</div>
# 	</script>
# <script id="confirmModal.html" type="text/ng-template">
#         <div class="modal" role="dialog">
# 				<div class="modal-confirm">
#                     <div class="modal-close">
#                         <button class="racing-icon close" type="button" ng-click="closeModal()"><span class="racing-icon">N</span></button>
#                     </div>
# 					<div class="modal-header">
# 			            <img src="/resources/racing/img/logos/logo-racing-plus.png" />
# 						<h3 class="modal-title">Confirm your account</h3>
# 					</div>
# 					<div class="modal-body tcenter">
# 						<span>Your account is currently in restriction mode. Please confirm your registration email to access Racing+ content.</span>
#                         <div class="btn-container">
#                             <a href="/plus/resend-confirm-token">RESEND MY CONFIRMATION EMAIL</a>
#                         </div>
# 					</div>
# 				</div>
# 		</div>
#     </script>
# <div id="masthead_0_ctl00_LoginButtonsPanel">
# <div class="login-signup-container">
# <a class="login-button nav-button txt-white" href="/plus" ng-click="showModal('login','default');" ng-href="#">Log in</a><a class="signup-button nav-button txt-white" href="/plus/signup">Sign up</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="drop-downs" ng-class="{'navbarHovering': anyDropDownActive || dropDownActive()}">
# <div class="drop-down racing-dd" ng-class="{'exposed': dropDowns[0].active}" ng-mouseenter="dropDowns[0].active = true;" ng-mouseleave="dropDowns[0].active = false;">
# <div class="container">
# <div class="inner-container">
# <div class="cols">
# <div class="col">
# <div class="title">
# <h3>
#         Racing
#     </h3>
# </div>
# <div class="widget box link-list-widget">
# <div class="box-content nopadding">
# <ul class="vlist">
# <li><a class="linked" href="https://www.racing.com/todays-racing?utm_source=mainnav&amp;utm_medium=racing&amp;utm_campaign=todaysracing" target="">Today's Racing</a></li>
# <li><a class="linked" href="https://www.racing.com/todays-racing?utm_source=mainnav&amp;utm_medium=racing&amp;utm_campaign=results#/results" target="">Latest Results</a></li>
# <li><a class="linked" href="https://www.racing.com/live-racing?utm_source=mainnav&amp;utm_medium=racing&amp;utm_campaign=watchliveracing" target="">Watch Live Racing</a></li>
# <li><a class="linked" href="https://www.racing.com/calendar?utm_source=mainnav&amp;utm_medium=racing&amp;utm_campaign=racingcalendar#/month-view" target="">Racing Calendar</a></li>
# <li><a class="linked" href="https://www.racing.com/jumpouts-and-trial-calendar?utm_source=mainnav&amp;utm_medium=racing&amp;utm_campaign=vicjumpoutsreplay" target="">VIC Jumpout Replays</a></li>
# <li><a class="linked" href="https://www.racing.com/jockeys?utm_source=mainnav&amp;utm_medium=racing&amp;utm_campaign=jockeypremierships" target="">Jockey Premiership</a></li>
# <li><a class="linked" href="https://www.racing.com/trainers?utm_source=mainnav&amp;utm_medium=racing&amp;utm_campaign=trainerpremierships" target="">Trainer Premiership</a></li>
# <li><a class="linked" href="https://www.racing.com/horses?utm_source=mainnav&amp;utm_medium=racing&amp;utm_campaign=horsesmostwins" target="">Horses - Most Wins</a></li>
# <li><a class="linked" href="https://www.racing.com/racingplus?utm_source=mainnav&amp;utm_medium=racing&amp;utm_campaign=racingplus" target="">Racing+</a></li>
# <li><a class="linked" href="https://www.racing.com/talent?utm_source=mainnav&amp;utm_medium=racing&amp;utm_campaign=formanalystprofiles" target="">Form Analyst Profiles</a></li>
# <li><a class="linked" href="https://www.racing.com/app?utm_source=mainnav&amp;utm_medium=racing&amp;utm_campaign=downloadtheapp" target="">Download the Racing.com App</a></li>
# <li><a class="linked" href="https://www.racing.com/club-events-and-memberships?utm_source=mainnav&amp;utm_medium=racing&amp;utm_campaign=clubeventsandmemberships" target="">Club Events &amp; Memberships</a></li>
# </ul>
# </div>
# </div>
# </div>
# <span class="spacer"></span>
# <div class="col span-2">
# <div class="title">
# <h3>Today's Racing</h3>
# </div>
# <ul class="vlist list-races nav">
# <li class="race MetroMeet">
# <a href="/form/2020-05-04/ipswich">
# <span class="border"></span>
# <span class="race-name">Ipswich</span>
# <span class="no-of-races">
# <span>7 Races</span>
# </span>
# </a>
# </li>
# <li class="race CountryMeet">
# <a href="/form/2020-05-04/bet365-echuca">
# <span class="border"></span>
# <span class="race-name">bet365 Echuca</span>
# <span class="no-of-races">
# <span>9 Races</span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# <span class="spacer"></span>
# <div class="col span-2">
# <div class="title">
# <h3>Tomorrow</h3>
# </div>
# <ul class="vlist list-races nav">
# <li class="race CountryMeet">
# <a href="/form/2020-05-05/warrnambool">
# <span class="border"></span>
# <span class="race-name">Warrnambool</span>
# <span class="no-of-races">
# <span>8 Races</span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# <span class="spacer"></span>
# <div class="col span-2">
# <div class="title">
# <h3>Yesterday's Results</h3>
# </div>
# <ul class="vlist list-races nav">
# <li class="race CountryMeet">
# <a href="/form/2020-05-03/bendigo">
# <span class="border"></span>
# <span class="race-name">Bendigo</span>
# <span class="no-of-races">
# <span>8 Races</span>
# </span>
# </a>
# </li>
# <li class="race CountryMeet">
# <a href="/form/2020-05-03/bordertown">
# <span class="border"></span>
# <span class="race-name">Bordertown</span>
# <span class="no-of-races">
# <span>8 Races</span>
# </span>
# </a>
# </li>
# <li class="race CountryMeet">
# <a href="/form/2020-05-03/bet365-bairnsdale">
# <span class="border"></span>
# <span class="race-name">bet365 Bairnsdale</span>
# <span class="no-of-races">
# <span>8 Races</span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="drop-down news-dd" ng-class="{'exposed': dropDowns[1].active}" ng-mouseenter="dropDowns[1].active = true;" ng-mouseleave="dropDowns[1].active = false;">
# <div class="container">
# <div class="inner-container">
# <div class="cols">
# <div class="col">
# <div class="title">
# <h3>
#         News
#     </h3>
# </div>
# <div class="widget box link-list-widget">
# <div class="box-content nopadding">
# <ul class="vlist">
# <li><a class="linked" href="https://www.racing.com/news?utm_source=mainnav&amp;utm_medium=news&amp;utm_campaign=latestnews" target="">Latest News</a></li>
# <li><a class="linked" href="https://www.racing.com/international?utm_source=mainnav&amp;utm_medium=news&amp;utm_campaign=internationalnews" target="">International News</a></li>
# <li><a class="linked" href="https://www.racing.com/podcasts?utm_source=mainnav&amp;utm_medium=news&amp;utm_campaign=latestpodcasts" target="">Latest Podcasts</a></li>
# <li><a class="linked" href="https://www.racing.com/videos?utm_source=mainnav&amp;utm_medium=news&amp;utm_campaign=latestvideos" target="">Latest Videos</a></li>
# <li><a class="linked" href="https://www.racing.com/videos/news-updates?utm_source=mainnav&amp;utm_medium=news&amp;utm_campaign=newsupdates" target="">News Updates</a></li>
# </ul>
# </div>
# </div>
# </div>
# <span class="spacer"></span>
# <div class="col">
# <div class="title">
# <h3>
#         Featured
#     </h3>
# </div>
# <div class="widget box link-list-widget">
# <div class="box-content nopadding">
# <ul class="vlist">
# <li><a class="linked" href="/lovethehorse" target="">Love The Horse</a></li>
# <li><a class="linked" href="/all-star-mile" target="">The All-Star Mile</a></li>
# <li><a class="linked" href="/form-analyst" target="">Form Analyst</a></li>
# <li><a class="linked" href="https://www.racing.com/news/2020-04-24/get-on-tips---apr-25" target="">Get On Tips</a></li>
# <li><a class="linked" href="/sectional-stars" target="">Sectional Stars</a></li>
# <li><a class="linked" href="/inglis-sales" target="">Inglis Sales</a></li>
# <li><a class="linked" href="/magic-millions-sales" target="">Magic Millions Sales</a></li>
# <li><a class="linked" href="/new-zealand-bloodstock" target="">NZB Karaka Sale</a></li>
# </ul>
# </div>
# </div>
# </div>
# <span class="spacer"></span>
# <div class="col span-2">
# <div class="widget featured-news">
# <!-- FEATURED -->
# <a class="wrap-link" href="https://www.racing.com/news/2020-05-03/news-mike-symons-warrnambool-preview">
# <div class="thumb t tcenter">
# <div class="banner-marquee">
# <span class="text">Hot Topic</span>
# <span class="triangle-upper"></span>
# <span class="triangle-lower"></span>
# </div>
# <div class="img-container">
# <img alt="Zed Em" height="273" src="//cdn.racing.com/-/media/racing/horses/z/zedem2019grandannual_660x380rp.jpg?h=273&amp;la=en&amp;w=410&amp;crop=1" width="410"/>
# </div>
# </div>
# <div class="desc c">
# <div class="inner-container">
# <h4 class="title">
#                         Mike Symons’ 'Bool Preview
#                     </h4>
# <p class="date small">
#                         3 May, 2020
#                     </p>
# </div>
# </div>
# </a>
# </div>
# </div>
# <span class="spacer"></span>
# <div class="col span-3">
# <div class="widget long-news-img-txt">
# <ul class="runners-up-news vlist">
# <li>
# <a href="https://www.racing.com/news/2020-05-03/an-early-look-echuca">
# <div class="img">
# <img alt="An Early Look" crop="True" src="//cdn.racing.com/-/media/racing/raceday-hub/daily-tips/early_look.jpg?h=85&amp;w=145&amp;la=en&amp;hash=567B3AA678D416CEAFC2A0D3C4A5D9B2FE60B5D5"/>
# </div>
# <div class="title-time">
# <div class="inner-container">
# <h4>An Early Look - Echuca</h4>
# <p class="small date">3 May, 2020</p>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a href="https://www.racing.com/news/2020-05-03/news-richards-calls-over-on-garners-campaign">
# <div class="img">
# <img alt="Garner" crop="True" src="//cdn.racing.com/-/media/racing/horses/g/garnerflemington_660x380rp.jpg?h=85&amp;w=145&amp;la=en&amp;hash=1888AB3DF497B8CB0C5814A0DDCEBF07E325F909"/>
# </div>
# <div class="title-time">
# <div class="inner-container">
# <h4>Richards calls over on Garner’s campaign</h4>
# <p class="small date">3 May, 2020</p>
# </div>
# </div>
# </a>
# </li>
# <li>
# <a href="https://www.racing.com/news/2020-05-02/news-reds-stocks-rise-at-sandown">
# <div class="img">
# <img alt="Rising Red wins at Sandown Lakeside (Image: Racing Photos/Pat Scala)" crop="True" src="//cdn.racing.com/-/media/racing/horses/r/risingred020520_660x380rp.jpg?h=85&amp;w=145&amp;la=en&amp;hash=04251FA91A4B8CA7CB1523DE27022F822E3A5C68"/>
# </div>
# <div class="title-time">
# <div class="inner-container">
# <h4>Red's stocks rise at Sandown</h4>
# <p class="small date">2 May, 2020</p>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="drop-down video-dd" ng-class="{'exposed': dropDowns[2].active}" ng-mouseenter="dropDowns[2].active = true;" ng-mouseleave="dropDowns[2].active = false;">
# <div class="container">
# <div class="inner-container">
# <div class="cols">
# <div class="col">
# <div class="title">
# <h3>
#         Video
#     </h3>
# </div>
# <div class="widget box link-list-widget">
# <div class="box-content nopadding">
# <ul class="vlist">
# <li><a class="linked" href="/videos" target="">Latest Videos</a></li>
# <li><a class="linked" href="/shows" target="">Latest TV Shows</a></li>
# <li><a class="linked" href="/videos/race-replays" target="">Latest Race Replays</a></li>
# <li><a class="linked" href="/videos/trial-replays" target="">Latest Trial Replays</a></li>
# <li><a class="linked" href="/videos/post-race-interviews" target="">Post Race Interviews</a></li>
# <li><a class="linked" href="/videos/stewards-vision" target="">Stewards Vision</a></li>
# <li><a class="linked" href="/videos/news-updates" target="">News Updates</a></li>
# </ul>
# </div>
# </div>
# </div>
# <span class="spacer"></span>
# <div class="col">
# <div class="title">
# <h3>
#         TV Shows
#     </h3>
# </div>
# <div class="widget box link-list-widget">
# <div class="box-content nopadding">
# <ul class="vlist">
# <li><a class="linked" href="/shows/after-the-last" target="">After The Last</a></li>
# <li><a class="linked" href="/shows/all-clear" target="">All Clear</a></li>
# ...
# </a>
# </li>
# <li class="logo-vrc">
# <a href="http://www.flemington.com.au" onclick="trackGAEvent('footer','club-vrc','click');" target="_blank">
# <svg id="Layer_1" viewbox="0 0 386.58 128.04" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><style>.cls-1{fill:#fff;}</style></defs><path class="cls-1" d="M33.84,52.34a23.17,23.17,0,0,0-2.35.82l2.35,5.7Z"></path><path class="cls-1" d="M34.55,94.66c0-.29,0-.59,0-.9l-.61-1.54-3.28-8.3L29.5,81l-2.45-6.18v18C27,101,26.33,101.9,24.62,103c-.13.07-.16.25.09.25H36.87c.18,0,.24-.15.08-.25C35.38,102,34.69,101.15,34.55,94.66Z"></path><path class="cls-1" d="M62.59,32.15c1.17.21,2,1.48,1.09,4.46-.18.6-1.54,4.58-1.94,5.41L61,43.9c.82.43,1.59.85,2.31,1.25.94.52,1.83,1,2.64,1.41l.36.19c.21.11.68.36,1.13.55l3-7.68.47-1.15c2-4.79,3.28-5.86,4.43-6.32.13,0,.14-.26-.09-.26H62.68C62.42,31.9,62.46,32.12
# </li>
# </ul>
# </div>
# <div class="container copyright-tnc">
#             © 2020 Racing Victoria Limited (RV) and other parties working with it. VIC and SA racing materials, including fields, form and results, is subject to copyright which is owned respectively by RV and TRSA and other parties working with them.
#         </div>
# </div>
# </div>
# <!-- Video Modal Player -->
# <div class="hide-dialog" modal-dialog="" show="false">
# <div class="modal-brightcove" id="divModalVideoPlayer" ng-init="playerKey='AQ~~,AAADJeoKm4k~,7HrqJxGnnCDf_e0SlIkgtGBk2zRNjDQw';playerId=3546749388001;bgColor='#FFFFFF';"></div>
# <div class="gallery-wrapper" id="modal-photo-gallery" modal-photo="" ng-controller="galleryController"></div>
# <div class="modal-photo-finish"></div>
# </div>
# <!-- Sticky Ad -->
# </div>
# <div id="isAkamaiSwitchActive">
# <div id="loadProfile" ng-controller="idController" ng-init="idBaseUrl='https://id.racing.com/'; init();"></div>
# </div>
# <!-- WSP Banner -->
# <div class="wspbanner">
# <div class="wspbanner__screen"></div>
# <!-- /305590751/racing/WSPformdesktop -->
# <div id="div-gpt-ad-1576552757651-0" style="width: 624px; height: 56px;">
# <script>
#     googletag.cmd.push(function() { googletag.display('div-gpt-ad-1576552757651-0'); });
#   </script>
# </div>
# </div>
# <div class="c-form-lv" ng-cloak="" ng-controller="inlineVisionController">
# <div class="c-form-lv__inner c-form-lv__inner--advert" ng-class="{'c-form-lv__inner--closed': !inlineEnabled}">
# <iframe allowfullscreen="true" class="c-form-lv__iframe c-form-lv__iframe--advert" ng-if="inlineEnabled" scrolling="no" src="/live-vision.aspx?embedded_mode=true">
# </iframe>
# </div>
# <div class="c-form-lv__toolbar">
# <div class="c-form-lv__title-bar">
# <a href="javascript:void(0);" ng-click="loadUserStateModal(false);">
# <span class="c-form-lv__title">
# <span ng-hide="inlineEnabled">Watch Live</span>
# <span ng-hide="!inlineEnabled">On Air</span>
#                          <span class="c-dot" style="top: 0;">•</span>
# </span>
# </a>
# <div class="c-form-lv__marquee" ng-controller="epgController" ng-init="initInlineLiveVision(0, 2);">
# <a href="javascript:void(0);" ng-click="loadUserStateModal(false);">
# <div class="c-menu-watch-live__marquee" style="width: 192px">
# <div class="c-menu-watch-live__marquee-text">
# <div>
# <span style="-webkit-font-smoothing: antialiased;">{{currentProgram.title}}</span>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="c-form-lv__buttons">
# <a class="c-form-lv__popout" href="javascript:void(0);" ng-click="loadUserStateModal(false);" ng-hide="!inlineEnabled"></a>
# <a class="c-form-lv__toggle" href="javascript:void(0);" ng-class="{'c-form-lv__toggle--close': inlineEnabled}" ng-click="loadUserStateModal(false);"></a>
# </div>
# </div>
# </div>
# </div>
# <!-- START Nielsen Online SiteCensus V6.0 -->
# <!-- COPYRIGHT 2012 Nielsen Online -->
# <script src="//secure-au.imrworldwide.com/v60.js" type="text/javascript">
# </script>
# <script type="text/javascript">
#  var pvar = { cid: "au-racingvic", content: "0", server: "secure-au" };
#  var trac = nol_t(pvar);
#  trac.record().post();
# </script>
# <noscript>
# <div>
# <img alt="" height="1" src="//secure-au.imrworldwide.com/cgi-bin/m?ci=au-racingvic&amp;cg=0&amp;cc=1&amp;ts=noscript" width="1">
# </img></div>
# </noscript>
# <!-- END Nielsen Online SiteCensus V6.0 -->
# <style>
# div[ng-controller="editablePageController"] .text-promo-widget .text-promo-box.nolink *{
# pointer-events:all !important;
# }
# </style>
# <!-- Generic Landing Page -->
# <style>
# p.visible-mobile{
# display:none;
# }
# .bg-container{
# padding-top: 0px;
# }
# .animate{
# opacity: 1!important;
# }
#
# </style>
# <!-- Footer Copyright -->
# <style>
# .copyright-tnc {
# font-size: 9px !important;
# }
# </style>
# <!-- Countdown Event Banner Widget Karaka 2018 -->
# <style>
# .countdown-event-banner-container .full-width.white-bg .container.content-990.padding-all .countdown-event-banner-widget .event-text .time-till-event{
# 	color: #fff;
# }
# .countdown-event-banner-container .full-width.white-bg .container.content-990.padding-all .countdown-event-banner-widget > div.button-group .rounded-button{
# 	color: #fff;
#        border-color: #fff;
# 	   background-color: #;
# }
# .countdown-event-banner-container .full-width.white-bg .container.content-990.padding-all .countdown-event-banner-widget > div.button-group .rounded-button:hover{
# border-color: #fff;
# background: #fff;
# color: #666666;
# }
# </style>
# <script>
# 	var navbar_custom_insert_desktop = $('.nav.navbar-nav.navbar-left');
# 	if (navbar_custom_insert_desktop.length > 0) {
# 		navbar_custom_insert_desktop.append('<li class=""> <a href="https://www.racing.com/replays" id="masthead_custom_linkout_desktop" target="_blank" class="external"> <span id="masthead_custom_linkout_span_desktop">Replay Hub</span> </a> </li>');
# 	}
#
# 	var navbar_custom_insert_mobile = $('.rv-menu.ham-menu.level-01 ul');
# 	if (navbar_custom_insert_mobile.length > 0) {
# 		navbar_custom_insert_mobile.append('<li class="cat primary"> <span class="text"> <a href="https://www.racing.com/replays" id="masthead_custom_linkout_mobile" target="_blank" class="external"> <span id="masthead_custom_linkout_span_mobile" class="text">Replay Hub</span> <span class="racing-icon go-out">d</span> </a> </span> </li>');
# 	}
# </script><!-- racing/relaxedracing -->
# <div id="1x1" style="height:1px">
# <script type="text/javascript">
# googletag.cmd.push(function() { googletag.display('1x1'); });
# </script>
# </div>
# <script type="text/javascript">
# setTimeout(function(){var a=document.createElement("script");
# var b=document.getElementsByTagName("script")[0];
# a.src=document.location.protocol+"//script.crazyegg.com/pages/scripts/0028/2648.js?"+Math.floor(new Date().getTime()/3600000);
# a.async=true;a.type="text/javascript";b.parentNode.insertBefore(a,b)}, 1);
# </script>
# <!-- Google Tag Manager - Legacy Browsers -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-NJJTCC" style="display:none;visibility:hidden" width="0"> </iframe></noscript>
# <!-- End Google Tag Manager - Legacy Browsers  -->
# <input id="MediaFramework_ItemId" name="MediaFramework_ItemId" type="hidden" value="2B6EBDE2945544C6B7A056897C2B6ED2"/></form>
# </body>
# </html>

# %%
print(type(html))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
Html_file= open("html_output.html","w")
Html_file.write(str(html))
Html_file.close()
